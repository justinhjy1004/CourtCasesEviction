# %%
import pandas as pd
import re

# %%
df = pd.read_csv("../02_cleaning/clean_all_cases.csv")

# %%
df = df[df.CASE_ID == "CI 02 16-935"]

# %%
df.head()
# Out:
#             CASE_ID                                       CASE_SUMMARY  \
# 36162  CI 02 16-935  In the County Court of Lancaster County       ...
#
#                                                  PARTIES  \
# 36162  Party                                Attorney ...
#
#                                           JUDGEMENT_INFO  \
# 36162  On 02/04/2016 judgment of Restitution of Premi...
#
#                                                  ACTIONS  \
# 36162  \n\n 12/21/2018 ***Storage***                 ...
#
#                                       CASE_NAME  \
# 36162  R.D. Hinkley & Associates, Inc v. Styles
#
#                              PLAINTIFF      DEFENDANT          JUDGE  \
# 36162  R.D. Hinkley & Associates, Inc.  Dwayne Styles  Rodney Reuter
#
#                       CLASSIFICATION  ... FILING_DATE CLOSING_DATE  \
# 36162  Real Property-Landlord/Tenant  ...  01/22/2016   03/30/2016
#
#              DECISION RESTITUTION  WRIT CONTINUED               STREET  \
# ...

# %%
action = df.loc[36162]["ACTIONS"]

# %%
print(action)
# Out:
#  12/21/2018 ***Storage***
#
#
#     *** Control Number 11203706 ***
#
#
#  12/20/2018 Satisfaction
#             This action initiated by party R.D. Hinkley & Associates, Inc.
#             Image ID  001631712C02
#
#
#  11/21/2018 Order-Release Garnishee
#             The document number is 03616275
#             This action initiated by Rodney Reuter
#             Image ID  D03650163C02
#
#
#  11/21/2018 Release of Garnishee (3:8F)
#             This action initiated by party R.D. Hinkley & Associates, Inc.
#             Image ID  000916185C02
#
#
#  10/18/2018 Order-Continuing Lien (3:8M)
#
#
#             The document number is 03616275
#             This action initiated by Rodney Reuter
#     01/07/2019
#             Image ID  D03626641C02
#
#
#  10/17/2018 App-Continuing Lien (3:8D)
#             This action initiated by party R.D. Hinkley & Associates, Inc.
#             Image ID  001574798C02
#
#
#  10/17/2018 Return-Garnishment Summons
# ...

# %%
x = re.search(r"Return-Cover", action)

# %%
x
# Out:
# <re.Match object; span=(16072, 16084), match='Return-Cover'>
